# %% [markdown]
# # LCoE calculator for geospatial grid-based electrification modelling

# %%
## This code has been developed in order to calculate the lcoe for grid extension processes under a geo-spatial content.
## Author: Alexandros Korkovelos
## Latest update: 30-10-2018

import pandas as pd
import numpy as np
from math import ceil, sqrt, pi, exp, log, copysign
import os
import matplotlib.pyplot as plt

import folium
import branca.colormap as cm
import json
from IPython.display import display, Markdown, HTML

# %% [markdown]
# ## General input parameters related to the transmission network

# %%
# Input parameters

HV_line_type = 69                  # kV
HV_line_cost = 110000              # $/km for 69kV
    
MV_line_type = 11                  # kV
MV_line_amperage_limit = 8.0       # Ampere (A)
MV_line_span = 25                  # km buffer area that can be reached by an MV line
MV_line_cost = 5000                # $/km  for 11-33 kV
MV_line_max_stretch = 50           # km length of MV line from main HV grid
#MV_increase_rate = 0.1            # (%)
    
LV_line_type = 0.240               # kV
LV_line_cost = 3000                # $/km for 0.4 kV
LV_line_max_length = 0.5           # km
    
service_Transf_type = 50           # kVa
service_Transf_cost = 3500         # $/unit of 50 kVa
max_nodes_per_serv_trans = 300     # maximum number of nodes served by each service transformer
MV_LV_sub_station_type = 400       # kVa
MV_LV_sub_station_cost = 10000     # $/unit of 50 kVa
HV_LV_sub_station_type = 1000      # kVa
HV_LV_sub_station_cost = 25000     # $/unit of 50 kVa
    
grid_fuel_cost = 0.076             # $/kWh
base_to_peak = 0.85                # for the sizing of needed capacity
trans_losses = 0.05                # (%)
distr_losses = 0.15                # (%)
trans_O_M = 0.03                   # (%) Operation and maintenance costs for T&D
disc_rate = 0.08                   # (%) discount rate
system_life = 30                   # years
con_cost_per_node = 100            # $

#simultaneous_usage = 0.06          # From (2)
power_factor = 0.9                 # From (1)
load_moment = 9643                 # for 50mm aluminum conductor under 5% voltage drop (kW m) (2)
project_life = 15                  # start - end year of analysis
fuel_cost = 0.076                  # $/kWh grid generating cost of electricity by the central grid
hours_per_year = 8760

# %% [markdown]
# ## Definition of a function that calculates the lcoe for certain inputs

# %%
def calc_lcoe(people, access_target, ppl_per_hh, productive_demand, productive_nodes, cluster_area, elec_dist):
    
# To prevent any div/0 error
    if people == 0:
        people = 0.00001 

    # Estimate total demand in settlement
    res_demand = people * access_target
    total_demand = res_demand + productive_demand
    total_nodes = (people/ppl_per_hh) + productive_nodes
    MV_tmp_length = 0
    No_of_LV_lines = 0
    No_of_MV_lines = 0
    No_of_HV_lines = 0
    No_of_HV_LV_subs = 0
    No_of_MV_LV_subs = 0
    
        # Estimate peak load in settlement
    average_load = total_demand/hours_per_year
    peak_load = average_load / base_to_peak
    print ("The peak load in this cluster is:", peak_load)
        
        # Sizing HV/MV
    HV_to_MV_lines  = HV_line_cost/MV_line_cost
    max_MV_load = MV_line_amperage_limit*MV_line_type*HV_to_MV_lines
    MV_temp_length = 0
    print ("The max MV load is:", max_MV_load)
    
    if peak_load <= max_MV_load and MV_temp_length <= MV_line_max_stretch:
        MV_amperage = MV_LV_sub_station_type/MV_line_type
        No_of_MV_lines = ceil(peak_load/(MV_amperage*MV_line_type*(1-trans_losses)))
        MV_km = elec_dist * No_of_MV_lines
        HV_km = 0
        MV_temp_length =+ elec_dist
        No_of_MV_LV_subs = 1  
    elif peak_load >= max_MV_load or MV_temp_length >= MV_line_max_stretch:
        HV_amperage = HV_LV_sub_station_type/HV_line_type
        No_of_HV_lines = ceil(peak_load/(HV_amperage*HV_line_type*(1-trans_losses)))
        HV_km = elec_dist * No_of_HV_lines
        MV_km = 0
        MV_temp_length = 0
        No_of_HV_LV_subs = 1
    # Unecessary here but keep just in case
    else:                           
        HV_km = 0
        No_of_MV_LV_subs = 0
        MV_km = 0
        No_of_HV_LV_subs = 0
        
        # Sizing service transformers in settlement 
    Smax = peak_load/power_factor
    no_of_service_transf = ceil(Smax/service_Transf_type)
        
        #Sizing LV lines in settlement
    LV_line_unit = 2 * (load_moment/1000/(peak_load*(total_nodes/max_nodes_per_serv_trans)*((total_nodes/max_nodes_per_serv_trans)+1)))       # Assumes that the load is destributed evenly among all demand nodes
    LV_area_limit = cluster_area/(no_of_service_transf*LV_line_max_length*LV_line_unit)
    LV_line_amperage = service_Transf_type/LV_line_type
    LV_capacity_limit = (peak_load/(LV_line_type*LV_line_amperage*(1-distr_losses)))
    No_of_LV_lines = max(LV_area_limit,LV_capacity_limit)
    LV_km = ceil(No_of_LV_lines)*LV_line_unit
    
    print ("Cluster_distance:", MV_temp_length, "\nHV_km:", HV_km, "\nMV_km:", MV_km, "\nLV_km:", LV_km, "\nServ_Trans:", no_of_service_transf, "\nnodes:", total_nodes)
    
    print ("LV_line_unit:", LV_line_unit, "\nLV_area_limit:",  LV_area_limit, "\nLV_line_amperage", LV_line_amperage, "\nLV_capacity_limit:", LV_capacity_limit, "\nNo_of_LV_lines:", No_of_LV_lines)

    print ("HV_cost:", HV_km * HV_line_cost + (No_of_HV_LV_subs*HV_LV_sub_station_cost),
      "\nMV_cost:", MV_km * MV_line_cost + (No_of_MV_LV_subs*MV_LV_sub_station_cost),
      "\nLV_cost:", LV_km * LV_line_cost,
      "\nServ_Trans_cost:", no_of_service_transf * service_Transf_cost,
      "\nnode_Connection_cost:", total_nodes * con_cost_per_node)
   
    ## Calculation of the investment cost
    td_investment_cost = (HV_km * HV_line_cost + (No_of_HV_LV_subs*HV_LV_sub_station_cost)) + \
                         (MV_km * MV_line_cost + (No_of_MV_LV_subs*MV_LV_sub_station_cost)) + \
                         (LV_km * LV_line_cost) + \
                         (no_of_service_transf * service_Transf_cost) +\
                         (total_nodes * con_cost_per_node)
    td_om_cost = td_investment_cost * trans_O_M
    total_investment_cost = td_investment_cost
    total_om_cost = td_om_cost
    print ("The total investment cost is estimated at:", total_investment_cost, "$")
    
    ## lcoe calculation 
    
    if system_life<project_life:
        reinvest_year = system_life
    else:
        reinvest_year = 0
        
    year = np.arange(project_life)
    generation_per_year = average_load*hours_per_year
    el_gen = generation_per_year * np.ones(project_life)
    el_gen[0] = 0
    discount_factor = (1 + disc_rate) ** year
    investments = np.zeros(project_life)
    investments[0] = total_investment_cost
    if reinvest_year:
        investments[reinvest_year] = total_investment_cost
    
    salvage = np.zeros(project_life)
    used_life = project_life
    if reinvest_year is not 0:
        used_life = project_life - system_life
        salvage[-1] = total_investment_cost * (1 - used_life / system_life)
    
    operation_and_maintenance = total_om_cost * np.ones(project_life)
    operation_and_maintenance[0] = 0
    fuel = el_gen * fuel_cost
    fuel[0] = 0
    
    discounted_costs = (investments + operation_and_maintenance + fuel - salvage) / discount_factor
    discounted_generation = el_gen / discount_factor
    lcoe = np.sum(discounted_costs) / np.sum(discounted_generation)
    
    print ("The lcoe is:", lcoe, "\n")
    return lcoe

# %% [markdown]
# ## Dynamic parameters that depend on the cluster

# %%
# Read the cluster characteristics from a csv file
df = pd.read_csv("Malawi_Clusters.csv")

# %%
# Dynamic inputs

people = df["Pop"]                                         # people
access_target = df["ResidentialDemandTierCustom"]          # kWh/pp/year
ppl_per_hh = df["NumPeoplePerHH"]                          # people per household
productive_demand = df["Productive_demand"]                # kWh/year/settlement
productive_nodes = df["Productive_nodes"]                  # other demand nodes
cluster_area = df["GridCellArea"]                          # km2
elec_dist = df["PlannedHVLineDist"]                        # distance of cluster area from closest electrified settlement

# %% [markdown]
# ## Run the function with the above inputs

# %%
#logging.info('Calculate grid LCOE')

df["lcoe"] = df.apply(lambda row: calc_lcoe(people=row["Pop"],
                                            access_target=row["ResidentialDemandTierCustom"],
                                            ppl_per_hh=row["NumPeoplePerHH"],
                                            productive_demand=row["Productive_demand"],
                                            productive_nodes=row["Productive_nodes"],
                                            cluster_area=row["GridCellArea"],
                                            elec_dist = row["PlannedHVLineDist"]),axis=1)
# Out:
# The peak load in this cluster is: 1977.4573629749295
# The max MV load is: 1936.0
# Cluster_distance: 0
# HV_km: 0.56391
# MV_km: 0
# LV_km: 26.570321854517154
# Serv_Trans: 44
# nodes: 39965.26574545455
# LV_line_unit: 5.454617089495747e-07
# LV_area_limit: 48711616.93338609
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 46.528408540586575
# No_of_LV_lines: 48711616.93338609
# HV_cost: 87030.1
# MV_cost: 0
# LV_cost: 79710.96556355146
# Serv_Trans_cost: 154000
# node_Connection_cost: 3996526.5745454547
# The total investment cost is estimated at: 4317267.640109006 $
# The lcoe is: 0.120361753756
#
# The peak load in this cluster is: 89769.0837880987
# The max MV load is: 1936.0
# Cluster_distance: 0
# HV_km: 4.6777999999999995
# MV_km: 0
# LV_km: 0.5611460754784587
# Serv_Trans: 1995
# nodes: 241495.9708
# LV_line_unit: 3.311303058933462e-10
# LV_area_limit: 1694638229.1227355
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 2112.2137361905575
# No_of_LV_lines: 1694638229.1227355
# HV_cost: 539558.0
# MV_cost: 0
# LV_cost: 1683.4382264353762
# Serv_Trans_cost: 6982500
# node_Connection_cost: 24149597.080000002
# The total investment cost is estimated at: 31673338.518226437 $
# The lcoe is: 0.0831692530893
#
# The peak load in this cluster is: 10326.48362536045
# The max MV load is: 1936.0
# Cluster_distance: 0
# HV_km: 51.41488
# MV_km: 0
# LV_km: 4.812839705396639
# Serv_Trans: 230
# nodes: 53865.60278181818
# LV_line_unit: 5.760989801651049e-08
# LV_area_limit: 83541888.07615308
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 242.97608530259882
# No_of_LV_lines: 83541888.07615308
# HV_cost: 5680636.8
# MV_cost: 0
# LV_cost: 14438.519116189918
# Serv_Trans_cost: 805000
# node_Connection_cost: 5386560.278181818
# The total investment cost is estimated at: 11886635.597298007 $
# The lcoe is: 0.0993890913762
#
# The peak load in this cluster is: 1361.8948686573724
# The max MV load is: 1936.0
# Cluster_distance: 2.556
# HV_km: 0
# MV_km: 10.224
# LV_km: 33.761959434330194
# Serv_Trans: 31
# nodes: 39044.2878
# LV_line_unit: 8.29663328948124e-07
# LV_area_limit: 40693565.90418826
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 32.04458514487935
# No_of_LV_lines: 40693565.90418826
# HV_cost: 0
# MV_cost: 61120.0
# LV_cost: 101285.87830299058
# Serv_Trans_cost: 108500
# node_Connection_cost: 3904428.78
# The total investment cost is estimated at: 4175334.6583029903 $
# The lcoe is: 0.138295197816
#
# The peak load in this cluster is: 6139.536785741937
# The max MV load is: 1936.0
# Cluster_distance: 0
# HV_km: 210.40816999999998
# MV_km: 0
# LV_km: 5.558223787498522
# Serv_Trans: 137
# nodes: 30018.599018181816
# LV_line_unit: 3.106343776870509e-07
# LV_area_limit: 17893137.55618729
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 144.45968907628088
# No_of_LV_lines: 17893137.55618729
# HV_cost: 23169898.7
# MV_cost: 0
# LV_cost: 16674.671362495566
# Serv_Trans_cost: 479500
# node_Connection_cost: 3001859.9018181814
# The total investment cost is estimated at: 26667933.27318068 $
# The lcoe is: 0.164259327972
#
# The peak load in this cluster is: 28396.43049487336
# The max MV load is: 1936.0
# Cluster_distance: 0
# HV_km: 107.5371
# MV_km: 0
# LV_km: 1.1459059823396467
# Serv_Trans: 632
# nodes: 196853.52232
# LV_line_unit: 1.5749732782206802e-09
# LV_area_limit: 727571697.1574533
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 668.1513057617261
# No_of_LV_lines: 727571697.1574533
# HV_cost: 11854081.0
# MV_cost: 0
# LV_cost: 3437.71794701894
# Serv_Trans_cost: 2212000
# node_Connection_cost: 19685352.232
# The total investment cost is estimated at: 33754870.94994702 $
# The lcoe is: 0.100153471692
#
# The peak load in this cluster is: 3445.7981641970187
# The max MV load is: 1936.0
# Cluster_distance: 0
# HV_km: 197.44408
# MV_km: 0
# LV_km: 7.277688256519988
# Serv_Trans: 77
# nodes: 31030.937072727273
# LV_line_unit: 5.181154722627614e-07
# LV_area_limit: 14046459.103844179
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 81.07760386345926
# No_of_LV_lines: 14046459.103844179
# HV_cost: 21743848.8
# MV_cost: 0
# LV_cost: 21833.064769559962
# Serv_Trans_cost: 269500
# node_Connection_cost: 3103093.707272727
# The total investment cost is estimated at: 25138275.572042286 $
# The lcoe is: 0.22423559804
#
# The peak load in this cluster is: 446.2410609643369
# The max MV load is: 1936.0
# Cluster_distance: 20.8848
# HV_km: 0
# MV_km: 41.7696
# LV_km: 34.638681930104376
# Serv_Trans: 10
# nodes: 10619.45968
# LV_line_unit: 3.354374694241022e-05
# LV_area_limit: 1032641.4058474025
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 10.499789669749104
# No_of_LV_lines: 1032641.4058474025
# HV_cost: 0
# MV_cost: 218847.99999999997
# LV_cost: 103916.04579031313
# Serv_Trans_cost: 35000
# node_Connection_cost: 1061945.9679999999
# The total investment cost is estimated at: 1419710.013790313 $
# The lcoe is: 0.140645303458
#
# The peak load in this cluster is: 887.918894530196
# The max MV load is: 1936.0
# Cluster_distance: 15.66035
# HV_km: 0
# MV_km: 46.981049999999996
# LV_km: 9.611528291566497
# Serv_Trans: 20
# nodes: 10437.029605454545
# LV_line_unit: 1.7444169912169588e-05
# LV_area_limit: 550987.3527025618
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 20.892209283063433
# No_of_LV_lines: 550987.3527025618
# HV_cost: 0
# MV_cost: 244905.24999999997
# LV_cost: 28834.584874699493
# Serv_Trans_cost: 70000
# node_Connection_cost: 1043702.9605454545
# The total investment cost is estimated at: 1387442.795420154 $
# The lcoe is: 0.107750359772
#
# The peak load in this cluster is: 1432.7621602525226
# The max MV load is: 1936.0
# Cluster_distance: 12.33884
# HV_km: 0
# MV_km: 49.35536
# LV_km: 5.386593335434225
# Serv_Trans: 32
# nodes: 13222.719310909091
# LV_line_unit: 6.775256730090254e-06
# LV_area_limit: 795038.0464665056
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 33.71205082947112
# No_of_LV_lines: 795038.0464665056
# HV_cost: 0
# MV_cost: 256776.8
# LV_cost: 16159.780006302675
# Serv_Trans_cost: 112000
# node_Connection_cost: 1322271.931090909
# The total investment cost is estimated at: 1707208.5110972119 $
# The lcoe is: 0.100211367867
#
# The peak load in this cluster is: 952.5672648899708
# The max MV load is: 1936.0
# Cluster_distance: 24.437820000000002
# HV_km: 0
# MV_km: 73.31346
# LV_km: 7.511564997301686
# Serv_Trans: 22
# nodes: 7505.570089090909
# LV_line_unit: 3.110288727573812e-05
# LV_area_limit: 241506.1670743502
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 22.413347409175785
# No_of_LV_lines: 241506.1670743502
# HV_cost: 0
# MV_cost: 376567.30000000005
# LV_cost: 22534.694991905057
# Serv_Trans_cost: 77000
# node_Connection_cost: 750557.0089090909
# The total investment cost is estimated at: 1226659.003900996 $
# The lcoe is: 0.102165862838
#
# The peak load in this cluster is: 1156.3973279847028
# The max MV load is: 1936.0
# Cluster_distance: 3.52711
# HV_km: 0
# MV_km: 14.10844
# LV_km: 6.218347373094168
# Serv_Trans: 26
# nodes: 23002.4606
# LV_line_unit: 2.8002803605369715e-06
# LV_area_limit: 2220615.8392956466
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 27.209348893757713
# No_of_LV_lines: 2220615.8392956466
# HV_cost: 0
# MV_cost: 80542.2
# LV_cost: 18655.0421192825
# Serv_Trans_cost: 91000
# node_Connection_cost: 2300246.06
# The total investment cost is estimated at: 2490443.3021192825 $
# The lcoe is: 0.119759912184
#
# The peak load in this cluster is: 320.31799742262507
# The max MV load is: 1936.0
# Cluster_distance: 6.24044
# HV_km: 0
# MV_km: 6.24044
# LV_km: 20.014373078805434
# Serv_Trans: 8
# nodes: 6605.588972727273
# LV_line_unit: 0.00011879305725159177
# LV_area_limit: 168480.21646258133
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 7.536894057002943
# No_of_LV_lines: 168480.21646258133
# HV_cost: 0
# MV_cost: 41202.2
# LV_cost: 60043.1192364163
# Serv_Trans_cost: 28000
# node_Connection_cost: 660558.8972727273
# The total investment cost is estimated at: 789804.2165091436 $
# The lcoe is: 0.126100835645
#
# The peak load in this cluster is: 1152.8341627378704
# The max MV load is: 1936.0
# Cluster_distance: 30.19308
# HV_km: 0
# MV_km: 120.77232
# LV_km: 5.529331617027042
# Serv_Trans: 26
# nodes: 5563.265765454546
# LV_line_unit: 4.6158155596222106e-05
# LV_area_limit: 119790.89830724258
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 27.125509711479303
# No_of_LV_lines: 119790.89830724258
# HV_cost: 0
# MV_cost: 613861.6
# LV_cost: 16587.994851081126
# Serv_Trans_cost: 91000
# node_Connection_cost: 556326.5765454547
# The total investment cost is estimated at: 1277776.1713965358 $
# The lcoe is: 0.0985213702037
#
# The peak load in this cluster is: 3283.1217621710707
# The max MV load is: 1936.0
# Cluster_distance: 0
# HV_km: 24.3438
# MV_km: 0
# LV_km: 1.93823197404957
# Serv_Trans: 73
# nodes: 12701.30160909091
# LV_line_unit: 3.201567182825218e-06
# LV_area_limit: 605400.2550496875
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 77.2499238157899
# No_of_LV_lines: 605400.2550496875
# HV_cost: 2702818.0
# MV_cost: 0
# LV_cost: 5814.6959221487095
# Serv_Trans_cost: 255500
# node_Connection_cost: 1270130.160909091
# The total investment cost is estimated at: 4234262.85683124 $
# The lcoe is: 0.102205816001
#
# The peak load in this cluster is: 421.6291715645421
# The max MV load is: 1936.0
# Cluster_distance: 7.51923
# HV_km: 0
# MV_km: 15.03846
# LV_km: 14.100449287786017
# Serv_Trans: 10
# nodes: 7114.118949090908
# LV_line_unit: 7.805007936380704e-05
# LV_area_limit: 180658.6760056335
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 9.920686389753932
# No_of_LV_lines: 180658.6760056335
# HV_cost: 0
# MV_cost: 85192.3
# LV_cost: 42301.34786335805
# Serv_Trans_cost: 35000
# node_Connection_cost: 711411.8949090908
# The total investment cost is estimated at: 873905.5427724489 $
# The lcoe is: 0.118115378208
#
# The peak load in this cluster is: 347.03488856452816
# The max MV load is: 1936.0
# Cluster_distance: 12.64606
# HV_km: 0
# MV_km: 12.64606
# LV_km: 16.376570441473465
# Serv_Trans: 8
# nodes: 7242.772007272727
# LV_line_unit: 9.155366594068151e-05
# LV_area_limit: 178873.64019492693
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 8.165526789753605
# No_of_LV_lines: 178873.64019492693
# HV_cost: 0
# MV_cost: 73230.3
# LV_cost: 49129.711324420394
# Serv_Trans_cost: 28000
# node_Connection_cost: 724277.2007272727
# The total investment cost is estimated at: 874637.2120516931 $
# The lcoe is: 0.127210813531
#
# The peak load in this cluster is: 50.620594365958794
# The max MV load is: 1936.0
# Cluster_distance: 12.26881
# HV_km: 0
# MV_km: 12.26881
# LV_km: 61.91374391232037
# Serv_Trans: 2
# nodes: 1451.246421818182
# LV_line_unit: 0.01349177248034874
# LV_area_limit: 4588.076925412246
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.1910728086107951
# No_of_LV_lines: 4588.076925412246
# HV_cost: 0
# MV_cost: 71344.05
# LV_cost: 185741.2317369611
# Serv_Trans_cost: 7000
# node_Connection_cost: 145124.6421818182
# The total investment cost is estimated at: 409209.9239187793 $
# The lcoe is: 0.240257715973
#
# The peak load in this cluster is: 303.93835727620785
# The max MV load is: 1936.0
# Cluster_distance: 21.09787
# HV_km: 0
# MV_km: 21.09787
# LV_km: 16.836964736612018
# Serv_Trans: 7
# nodes: 5752.6919890909085
# LV_line_unit: 0.0001640134501306501
# LV_area_limit: 102655.53561623521
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 7.151490759440184
# No_of_LV_lines: 102655.53561623521
# HV_cost: 0
# MV_cost: 115489.35
# LV_cost: 50510.89420983605
# Serv_Trans_cost: 24500
# node_Connection_cost: 575269.1989090908
# The total investment cost is estimated at: 765769.4431189268 $
# The lcoe is: 0.127194037586
#
# The peak load in this cluster is: 4206.160113184451
# The max MV load is: 1936.0
# Cluster_distance: 0
# HV_km: 7.21715
# MV_km: 0
# LV_km: 1.0463135723573418
# Serv_Trans: 94
# nodes: 14390.240205454546
# LV_line_unit: 1.952099412227267e-06
# LV_area_limit: 535993.5869063379
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 98.96847325139885
# No_of_LV_lines: 535993.5869063379
# HV_cost: 818886.5
# MV_cost: 0
# LV_cost: 3138.9407170720256
# Serv_Trans_cost: 329000
# node_Connection_cost: 1439024.0205454545
# The total investment cost is estimated at: 2590049.4612625265 $
# The lcoe is: 0.088512068674
#
# The peak load in this cluster is: 826.9428284017534
# The max MV load is: 1936.0
# Cluster_distance: 18.92091
# HV_km: 0
# MV_km: 56.76273
# LV_km: 4.840877730150968
# Serv_Trans: 19
# nodes: 7163.719961818182
# LV_line_unit: 3.925683204650741e-05
# LV_area_limit: 123312.62879693872
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 19.457478315335376
# No_of_LV_lines: 123312.62879693872
# HV_cost: 0
# MV_cost: 293813.64999999997
# LV_cost: 14522.633190452903
# Serv_Trans_cost: 66500
# node_Connection_cost: 716371.9961818182
# The total investment cost is estimated at: 1091208.2793722712 $
# The lcoe is: 0.102812606197
#
# The peak load in this cluster is: 1811.2449733629935
# The max MV load is: 1936.0
# Cluster_distance: 8.98396
# HV_km: 0
# MV_km: 44.919799999999995
# LV_km: 2.1016602363555643
# Serv_Trans: 41
# nodes: 5898.795160000001
# LV_line_unit: 2.6208180922492107e-05
# LV_area_limit: 80190.50705154121
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 42.617528785011615
# No_of_LV_lines: 80190.50705154121
# HV_cost: 0
# MV_cost: 234598.99999999997
# LV_cost: 6304.980709066693
# Serv_Trans_cost: 143500
# node_Connection_cost: 589879.5160000001
# The total investment cost is estimated at: 974283.4967090667 $
# The lcoe is: 0.0869298704731
#
# The peak load in this cluster is: 528.643040646011
# The max MV load is: 1936.0
# Cluster_distance: 0.13279000000000002
# HV_km: 0
# MV_km: 0.26558000000000004
# LV_km: 5.900641343746628
# Serv_Trans: 12
# nodes: 4774.27502
# LV_line_unit: 0.00013553164765019702
# LV_area_limit: 43536.387520075696
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 12.43865977990614
# No_of_LV_lines: 43536.387520075696
# HV_cost: 0
# MV_cost: 11327.9
# LV_cost: 17701.924031239883
# Serv_Trans_cost: 42000
# node_Connection_cost: 477427.502
# The total investment cost is estimated at: 548457.3260312398 $
# The lcoe is: 0.0970808047095
#
# The peak load in this cluster is: 48.647946051647885
# The max MV load is: 1936.0
# Cluster_distance: 12.47914
# HV_km: 0
# MV_km: 12.47914
# LV_km: 4.336243976442129
# Serv_Trans: 2
# nodes: 649.7607727272726
# LV_line_unit: 0.05781658635256171
# LV_area_limit: 74.76401276341484
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.1446575541564208
# No_of_LV_lines: 74.76401276341484
# HV_cost: 0
# MV_cost: 72395.7
# LV_cost: 13008.731929326386
# Serv_Trans_cost: 7000
# node_Connection_cost: 64976.07727272726
# The total investment cost is estimated at: 157380.50920205365 $
# The lcoe is: 0.141734490282
#
# The peak load in this cluster is: 23.516493714995907
# The max MV load is: 1936.0
# Cluster_distance: 27.33472
# HV_km: 0
# MV_km: 27.33472
# LV_km: 8.717271867577985
# Serv_Trans: 1
# nodes: 375.84326727272725
# LV_line_unit: 0.29057572891926614
# LV_area_limit: 29.60419313751446
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.5533292638822567
# No_of_LV_lines: 29.60419313751446
# HV_cost: 0
# MV_cost: 146673.6
# LV_cost: 26151.815602733954
# Serv_Trans_cost: 3500
# node_Connection_cost: 37584.326727272724
# The total investment cost is estimated at: 213909.74233000667 $
# The lcoe is: 0.260826763031
#
# The peak load in this cluster is: 151.37855949585452
# The max MV load is: 1936.0
# Cluster_distance: 2.1976
# HV_km: 0
# MV_km: 2.1976
# LV_km: 2.1510630114326985
# Serv_Trans: 4
# nodes: 893.3590436363636
# LV_line_unit: 0.010755315057163492
# LV_area_limit: 199.20569398596945
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 3.5618484587259887
# No_of_LV_lines: 199.20569398596945
# HV_cost: 0
# MV_cost: 20988.0
# LV_cost: 6453.189034298096
# Serv_Trans_cost: 14000
# node_Connection_cost: 89335.90436363636
# The total investment cost is estimated at: 130777.09339793446 $
# The lcoe is: 0.0935539224259
#
# The peak load in this cluster is: 31.240524080042974
# The max MV load is: 1936.0
# Cluster_distance: 5.42272
# HV_km: 0
# MV_km: 5.42272
# LV_km: 8.537864350728011
# Serv_Trans: 1
# nodes: 393.8904727272727
# LV_line_unit: 0.20328248454114312
# LV_area_limit: 41.36952585454026
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.7350711548245406
# No_of_LV_lines: 41.36952585454026
# HV_cost: 0
# MV_cost: 37113.6
# LV_cost: 25613.593052184035
# Serv_Trans_cost: 3500
# node_Connection_cost: 39389.04727272727
# The total investment cost is estimated at: 105616.24032491131 $
# The lcoe is: 0.14469407108
#
# The peak load in this cluster is: 190.44111433492526
# The max MV load is: 1936.0
# Cluster_distance: 2.62279
# HV_km: 0
# MV_km: 2.62279
# LV_km: 1.6842448695233632
# Serv_Trans: 5
# nodes: 1419.4242472727271
# LV_line_unit: 0.0037344675599187654
# LV_area_limit: 450.318545553675
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 4.480967396115888
# No_of_LV_lines: 450.318545553675
# HV_cost: 0
# MV_cost: 23113.95
# LV_cost: 5052.734608570089
# Serv_Trans_cost: 17500
# node_Connection_cost: 141942.4247272727
# The total investment cost is estimated at: 187609.1093358428 $
# The lcoe is: 0.0960170498161
#
# The peak load in this cluster is: 32.39588137074179
# The max MV load is: 1936.0
# Cluster_distance: 17.91864
# HV_km: 0
# MV_km: 17.91864
# LV_km: 8.433054356253386
# Serv_Trans: 1
# nodes: 338.3825109090909
# LV_line_unit: 0.24803101047804077
# LV_area_limit: 33.599427684216195
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.762256032252748
# No_of_LV_lines: 33.599427684216195
# HV_cost: 0
# MV_cost: 99593.2
# LV_cost: 25299.163068760157
# Serv_Trans_cost: 3500
# node_Connection_cost: 33838.25109090909
# The total investment cost is estimated at: 162230.61415966926 $
# The lcoe is: 0.177753621403
#
# The peak load in this cluster is: 33.665874219878766
# The max MV load is: 1936.0
# Cluster_distance: 24.56232
# HV_km: 0
# MV_km: 24.56232
# LV_km: 8.497007265632135
# Serv_Trans: 1
# nodes: 308.91255090909095
# LV_line_unit: 0.27409700856877856
# LV_area_limit: 30.255857381672392
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.7921382169383239
# No_of_LV_lines: 30.255857381672392
# HV_cost: 0
# MV_cost: 132811.6
# LV_cost: 25491.021796896406
# Serv_Trans_cost: 3500
# node_Connection_cost: 30891.255090909097
# The total investment cost is estimated at: 192693.87688780553 $
# The lcoe is: 0.192301383328
#
# The peak load in this cluster is: 498.58432316195933
# The max MV load is: 1936.0
# Cluster_distance: 1.82615
# HV_km: 0
# MV_km: 3.6523
# LV_km: 0.6896137807247054
# Serv_Trans: 12
# nodes: 1893.8206236363635
# LV_line_unit: 0.0008379268295561425
# LV_area_limit: 822.9218936677245
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 11.731395839104925
# No_of_LV_lines: 822.9218936677245
# HV_cost: 0
# MV_cost: 28261.5
# LV_cost: 2068.841342174116
# Serv_Trans_cost: 42000
# node_Connection_cost: 189382.06236363636
# The total investment cost is estimated at: 261712.4037058105 $
# The lcoe is: 0.0866657782377
#
# The peak load in this cluster is: 5.9059625250786905
# The max MV load is: 1936.0
# Cluster_distance: 7.7017
# HV_km: 0
# MV_km: 7.7017
# LV_km: 9.218456292366517
# Serv_Trans: 1
# nodes: 276.50488
# LV_line_unit: 1.8436912584733032
# LV_area_limit: 4.472972338562192
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.1389638241194986
# No_of_LV_lines: 4.472972338562192
# HV_cost: 0
# MV_cost: 48508.5
# LV_cost: 27655.36887709955
# Serv_Trans_cost: 3500
# node_Connection_cost: 27650.488
# The total investment cost is estimated at: 107314.35687709955 $
# The lcoe is: 0.445210465313
#
# The peak load in this cluster is: 77.78869500989398
# The max MV load is: 1936.0
# Cluster_distance: 5.78245
# HV_km: 0
# MV_km: 5.78245
# LV_km: 4.131792617620059
# Serv_Trans: 2
# nodes: 420.0219345454545
# LV_line_unit: 0.07378201102892963
# LV_area_limit: 55.72930234156632
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.8303222355269173
# No_of_LV_lines: 55.72930234156632
# HV_cost: 0
# MV_cost: 38912.25
# LV_cost: 12395.377852860178
# Serv_Trans_cost: 7000
# node_Connection_cost: 42002.19345454545
# The total investment cost is estimated at: 100309.82130740563 $
# The lcoe is: 0.102201963258
#
# The peak load in this cluster is: 3.394220722015811
# The max MV load is: 1936.0
# Cluster_distance: 9.16375
# HV_km: 0
# MV_km: 9.16375
# LV_km: 9.259577344016444
# Serv_Trans: 1
# nodes: 128.79607454545453
# LV_line_unit: 9.259577344016444
# LV_area_limit: 0.8870599266939299
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.07986401698860732
# No_of_LV_lines: 0.8870599266939299
# HV_cost: 0
# MV_cost: 55818.75
# LV_cost: 27778.73203204933
# Serv_Trans_cost: 3500
# node_Connection_cost: 12879.607454545454
# The total investment cost is estimated at: 99977.08948659478 $
# The lcoe is: 0.674504294947
#
# The peak load in this cluster is: 49.80377651478998
# The max MV load is: 1936.0
# Cluster_distance: 5.65064
# HV_km: 0
# MV_km: 5.65064
# LV_km: 4.1235552709876755
# Serv_Trans: 2
# nodes: 406.65258727272726
# LV_line_unit: 0.12128103738199046
# LV_area_limit: 33.81625098639711
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.171853565053882
# No_of_LV_lines: 33.81625098639711
# HV_cost: 0
# MV_cost: 38253.2
# LV_cost: 12370.665812963027
# Serv_Trans_cost: 7000
# node_Connection_cost: 40665.258727272725
# The total investment cost is estimated at: 98289.12454023575 $
# The lcoe is: 0.116100524543
#
# The peak load in this cluster is: 7.323093669593981
# The max MV load is: 1936.0
# Cluster_distance: 14.10079
# HV_km: 0
# MV_km: 14.10079
# LV_km: 9.949719980374459
# Serv_Trans: 1
# nodes: 156.5390109090909
# LV_line_unit: 3.3165733267914863
# LV_area_limit: 2.4722444499462433
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.1723080863433878
# No_of_LV_lines: 2.4722444499462433
# HV_cost: 0
# MV_cost: 80503.95
# LV_cost: 29849.159941123376
# Serv_Trans_cost: 3500
# node_Connection_cost: 15653.90109090909
# The total investment cost is estimated at: 129507.01103203246 $
# The lcoe is: 0.435339991563
#
# The peak load in this cluster is: 70.01893482969203
# The max MV load is: 1936.0
# Cluster_distance: 2.02806
# HV_km: 0
# MV_km: 2.02806
# LV_km: 4.111865224023719
# Serv_Trans: 2
# nodes: 1129.9282236363636
# LV_line_unit: 0.015342780686655665
# LV_area_limit: 267.204497263372
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.64750434893393
# No_of_LV_lines: 267.204497263372
# HV_cost: 0
# MV_cost: 20140.3
# LV_cost: 12335.595672071157
# Serv_Trans_cost: 7000
# node_Connection_cost: 112992.82236363635
# The total investment cost is estimated at: 152468.7180357075 $
# The lcoe is: 0.120245806057
#
# The peak load in this cluster is: 73.82569254959064
# The max MV load is: 1936.0
# Cluster_distance: 12.063310000000001
# HV_km: 0
# MV_km: 12.063310000000001
# LV_km: 4.115539405110589
# Serv_Trans: 2
# nodes: 674.3021618181818
# LV_line_unit: 0.035787299174874686
# LV_area_limit: 114.38918539217579
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.7370751188138975
# No_of_LV_lines: 114.38918539217579
# HV_cost: 0
# MV_cost: 70316.55
# LV_cost: 12346.618215331766
# Serv_Trans_cost: 7000
# node_Connection_cost: 67430.21618181818
# The total investment cost is estimated at: 157093.38439714996 $
# The lcoe is: 0.119237166858
#
# The peak load in this cluster is: 29.225802009791405
# The max MV load is: 1936.0
# Cluster_distance: 1.1546399999999999
# HV_km: 0
# MV_km: 1.1546399999999999
# LV_km: 8.270444463849698
# Serv_Trans: 1
# nodes: 484.8991309090909
# LV_line_unit: 0.15604612195942827
# LV_area_limit: 52.38297432425311
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.6876659296421507
# No_of_LV_lines: 52.38297432425311
# HV_cost: 0
# MV_cost: 15773.2
# LV_cost: 24811.333391549095
# Serv_Trans_cost: 3500
# node_Connection_cost: 48489.91309090909
# The total investment cost is estimated at: 92574.44648245818 $
# The lcoe is: 0.140362298994
#
# The peak load in this cluster is: 119.90835693344788
# The max MV load is: 1936.0
# Cluster_distance: 4.10135
# HV_km: 0
# MV_km: 4.10135
# LV_km: 2.7188607171184014
# Serv_Trans: 3
# nodes: 877.3170345454546
# LV_line_unit: 0.014014745964527842
# LV_area_limit: 193.825846495928
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 2.8213731043164207
# No_of_LV_lines: 193.825846495928
# HV_cost: 0
# MV_cost: 30506.75
# LV_cost: 8156.582151355205
# Serv_Trans_cost: 10500
# node_Connection_cost: 87731.70345454547
# The total investment cost is estimated at: 136895.0356059007 $
# The lcoe is: 0.0991977097046
#
# The peak load in this cluster is: 108.31721750436036
# The max MV load is: 1936.0
# Cluster_distance: 27.636809999999997
# HV_km: 0
# MV_km: 27.636809999999997
# LV_km: 2.7377677563262726
# Serv_Trans: 3
# nodes: 550.5376436363636
# LV_line_unit: 0.03422209695407841
# LV_area_limit: 79.06451018954512
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 2.5486404118673027
# No_of_LV_lines: 79.06451018954512
# HV_cost: 0
# MV_cost: 148184.05
# LV_cost: 8213.303268978818
# Serv_Trans_cost: 10500
# node_Connection_cost: 55053.76436363636
# The total investment cost is estimated at: 221951.11763261515 $
# The lcoe is: 0.117635779841
#
# The peak load in this cluster is: 62.43137803160186
# The max MV load is: 1936.0
# Cluster_distance: 3.79445
# HV_km: 0
# MV_km: 3.79445
# LV_km: 4.063402473084274
# Serv_Trans: 2
# nodes: 1239.7686345454547
# LV_line_unit: 0.014564166570194529
# LV_area_limit: 278.39835396402253
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.4689736007435732
# No_of_LV_lines: 278.39835396402253
# HV_cost: 0
# MV_cost: 28972.25
# LV_cost: 12190.207419252822
# Serv_Trans_cost: 7000
# node_Connection_cost: 123976.86345454547
# The total investment cost is estimated at: 172139.32087379828 $
# The lcoe is: 0.132025278811
#
# The peak load in this cluster is: 617.4240976947029
# The max MV load is: 1936.0
# Cluster_distance: 1.07031
# HV_km: 0
# MV_km: 2.14062
# LV_km: 0.5780561570075079
# Serv_Trans: 14
# nodes: 1986.5444636363636
# LV_line_unit: 0.0006189038083592161
# LV_area_limit: 933.7615371291255
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 14.527625828110658
# No_of_LV_lines: 933.7615371291255
# HV_cost: 0
# MV_cost: 20703.1
# LV_cost: 1734.1684710225236
# Serv_Trans_cost: 49000
# node_Connection_cost: 198654.44636363635
# The total investment cost is estimated at: 270091.7148346589 $
# The lcoe is: 0.0848886242757
#
# The peak load in this cluster is: 32.23245906663555
# The max MV load is: 1936.0
# Cluster_distance: 17.56236
# HV_km: 0
# MV_km: 17.56236
# LV_km: 8.041464517419026
# Serv_Trans: 1
# nodes: 1100.0896418181817
# LV_line_unit: 0.034962889206169676
# LV_area_limit: 229.69840829352384
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.7584108015678953
# No_of_LV_lines: 229.69840829352384
# HV_cost: 0
# MV_cost: 97811.8
# LV_cost: 24124.39355225708
# Serv_Trans_cost: 3500
# node_Connection_cost: 110008.96418181817
# The total investment cost is estimated at: 235445.15773407527 $
# The lcoe is: 0.22442367668
#
# The peak load in this cluster is: 74.42948721334773
# The max MV load is: 1936.0
# Cluster_distance: 24.93296
# HV_km: 0
# MV_km: 24.93296
# LV_km: 4.074376330450422
# Serv_Trans: 2
# nodes: 395.1959636363636
# LV_line_unit: 0.08488284021771712
# LV_area_limit: 47.231572243775986
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.75128205207877
# No_of_LV_lines: 47.231572243775986
# HV_cost: 0
# MV_cost: 134664.8
# LV_cost: 12223.128991351265
# Serv_Trans_cost: 7000
# node_Connection_cost: 39519.59636363636
# The total investment cost is estimated at: 193407.5253549876 $
# The lcoe is: 0.12880015575
#
# The peak load in this cluster is: 2.3402245577566405
# The max MV load is: 1936.0
# Cluster_distance: 8.17174
# HV_km: 0
# MV_km: 8.17174
# LV_km: 54.65296363568343
# Serv_Trans: 1
# nodes: 39.92379818181818
# LV_line_unit: 54.65296363568343
# LV_area_limit: 0.1458636361083827
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.05506410724133272
# No_of_LV_lines: 0.1458636361083827
# HV_cost: 0
# MV_cost: 50858.7
# LV_cost: 163958.89090705029
# Serv_Trans_cost: 3500
# node_Connection_cost: 3992.379818181818
# The total investment cost is estimated at: 222309.97072523212 $
# The lcoe is: 2.00622648965
#
# The peak load in this cluster is: 44.18439323444069
# The max MV load is: 1936.0
# Cluster_distance: 5.32327
# HV_km: 0
# MV_km: 5.32327
# LV_km: 7.958381542075669
# Serv_Trans: 1
# nodes: 533.1956036363637
# LV_line_unit: 0.08842646157861854
# LV_area_limit: 89.52274984973647
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.0396327819868398
# No_of_LV_lines: 89.52274984973647
# HV_cost: 0
# MV_cost: 36616.35
# LV_cost: 23875.144626227007
# Serv_Trans_cost: 3500
# node_Connection_cost: 53319.56036363637
# The total investment cost is estimated at: 117311.05498986338 $
# The lcoe is: 0.129948193607
#
# The peak load in this cluster is: 178.84140868205895
# The max MV load is: 1936.0
# Cluster_distance: 1.83835
# HV_km: 0
# MV_km: 1.83835
# LV_km: 1.9802739834002256
# Serv_Trans: 4
# nodes: 1147.6764890909092
# LV_line_unit: 0.005841516175221904
# LV_area_limit: 338.4232690111317
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 4.2080331454602105
# No_of_LV_lines: 338.4232690111317
# HV_cost: 0
# MV_cost: 19191.75
# LV_cost: 5940.821950200677
# Serv_Trans_cost: 14000
# node_Connection_cost: 114767.64890909092
# The total investment cost is estimated at: 153900.22085929158 $
# The lcoe is: 0.0934854987066
#
# The peak load in this cluster is: 114.16407530251143
# The max MV load is: 1936.0
# Cluster_distance: 6.2033
# HV_km: 0
# MV_km: 6.2033
# LV_km: 2.638550373454431
# Serv_Trans: 3
# nodes: 601.0983018181819
# LV_line_unit: 0.028069684823983306
# LV_area_limit: 93.52367212035786
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 2.6862135365296806
# No_of_LV_lines: 93.52367212035786
# HV_cost: 0
# MV_cost: 41016.5
# LV_cost: 7915.651120363293
# Serv_Trans_cost: 10500
# node_Connection_cost: 60109.830181818186
# The total investment cost is estimated at: 119541.98130218148 $
# The lcoe is: 0.0972763854038
#
# The peak load in this cluster is: 45.887896512958015
# The max MV load is: 1936.0
# Cluster_distance: 5.52556
# HV_km: 0
# MV_km: 5.52556
# LV_km: 3.9384901577727778
# Serv_Trans: 2
# nodes: 933.9705818181818
# LV_line_unit: 0.03282075131477315
# LV_area_limit: 119.57404516311345
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.0797152120696003
# No_of_LV_lines: 119.57404516311345
# HV_cost: 0
# MV_cost: 37627.8
# LV_cost: 11815.470473318333
# Serv_Trans_cost: 7000
# node_Connection_cost: 93397.05818181818
# The total investment cost is estimated at: 149840.32865513652 $
# The lcoe is: 0.142349465567
#
# The peak load in this cluster is: 104.60132739791563
# The max MV load is: 1936.0
# Cluster_distance: 23.451970000000003
# HV_km: 0
# MV_km: 23.451970000000003
# LV_km: 2.631379245849893
# Serv_Trans: 3
# nodes: 553.8898781818182
# LV_line_unit: 0.035085056611331905
# LV_area_limit: 74.55899802714787
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 2.4612077034803677
# No_of_LV_lines: 74.55899802714787
# HV_cost: 0
# MV_cost: 127259.85000000002
# LV_cost: 7894.137737549679
# Serv_Trans_cost: 10500
# node_Connection_cost: 55388.98781818182
# The total investment cost is estimated at: 201042.9755557315 $
# The lcoe is: 0.115053374852
#
# The peak load in this cluster is: 35.00602729283333
# The max MV load is: 1936.0
# Cluster_distance: 24.30666
# HV_km: 0
# MV_km: 24.30666
# LV_km: 7.856696825000774
# Serv_Trans: 1
# nodes: 483.3744545454545
# LV_line_unit: 0.13094494708334622
# LV_area_limit: 59.76374174269526
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.8236712304196078
# No_of_LV_lines: 59.76374174269526
# HV_cost: 0
# MV_cost: 131533.3
# LV_cost: 23570.090475002322
# Serv_Trans_cost: 3500
# node_Connection_cost: 48337.44545454545
# The total investment cost is estimated at: 206940.8359295478 $
# The lcoe is: 0.196118592413
#
# The peak load in this cluster is: 42.987841584413665
# The max MV load is: 1936.0
# Cluster_distance: 19.84457
# HV_km: 0
# MV_km: 19.84457
# LV_km: 7.8581947002532315
# Serv_Trans: 1
# nodes: 746.3904436363636
# LV_line_unit: 0.05169864934377126
# LV_area_limit: 151.25694963522565
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.0114786255156156
# No_of_LV_lines: 151.25694963522565
# HV_cost: 0
# MV_cost: 109222.85
# LV_cost: 23574.584100759694
# Serv_Trans_cost: 3500
# node_Connection_cost: 74639.04436363635
# The total investment cost is estimated at: 210936.47846439606 $
# The lcoe is: 0.175704076183
#
# The peak load in this cluster is: 4.60084138804931
# The max MV load is: 1936.0
# Cluster_distance: 24.64412
# HV_km: 0
# MV_km: 24.64412
# LV_km: 7.912617174189822
# Serv_Trans: 1
# nodes: 193.30456727272724
# LV_line_unit: 3.956308587094911
# LV_area_limit: 1.9652915916018945
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.10825509148351317
# No_of_LV_lines: 1.9652915916018945
# HV_cost: 0
# MV_cost: 133220.6
# LV_cost: 23737.851522569465
# Serv_Trans_cost: 3500
# node_Connection_cost: 19330.456727272725
# The total investment cost is estimated at: 179788.90824984218 $
# The lcoe is: 0.870021927843
#
# The peak load in this cluster is: 162.10640235427263
# The max MV load is: 1936.0
# Cluster_distance: 9.112110000000001
# HV_km: 0
# MV_km: 9.112110000000001
# LV_km: 1.9456278840607755
# Serv_Trans: 4
# nodes: 909.7942672727273
# LV_line_unit: 0.009728139420303877
# LV_area_limit: 199.34233219895862
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 3.814268290688768
# No_of_LV_lines: 199.34233219895862
# HV_cost: 0
# MV_cost: 55560.55
# LV_cost: 5836.883652182327
# Serv_Trans_cost: 14000
# node_Connection_cost: 90979.42672727273
# The total investment cost is estimated at: 166376.86037945506 $
# The lcoe is: 0.096854492204
#
# The peak load in this cluster is: 66.09613519760521
# The max MV load is: 1936.0
# Cluster_distance: 3.60049
# HV_km: 0
# MV_km: 3.60049
# LV_km: 3.8741637919049636
# Serv_Trans: 2
# nodes: 1066.4980581818184
# LV_line_unit: 0.018019366473976575
# LV_area_limit: 214.80444418453598
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.5552031811201226
# No_of_LV_lines: 214.80444418453598
# HV_cost: 0
# MV_cost: 28002.45
# LV_cost: 11622.491375714892
# Serv_Trans_cost: 7000
# node_Connection_cost: 106649.80581818183
# The total investment cost is estimated at: 153274.74719389674 $
# The lcoe is: 0.123119579365
#
# The peak load in this cluster is: 73.67321058414299
# The max MV load is: 1936.0
# Cluster_distance: 1.89678
# HV_km: 0
# MV_km: 1.89678
# LV_km: 3.838318388936635
# Serv_Trans: 2
# nodes: 429.26089636363633
# LV_line_unit: 0.07526114488111049
# LV_area_limit: 50.92906845962724
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.733487307862188
# No_of_LV_lines: 50.92906845962724
# HV_cost: 0
# MV_cost: 19483.9
# LV_cost: 11514.955166809905
# Serv_Trans_cost: 7000
# node_Connection_cost: 42926.089636363635
# The total investment cost is estimated at: 80924.94480317354 $
# The lcoe is: 0.0983192541699
#
# The peak load in this cluster is: 25.948775991418525
# The max MV load is: 1936.0
# Cluster_distance: 11.915230000000001
# HV_km: 0
# MV_km: 11.915230000000001
# LV_km: 7.707330022467275
# Serv_Trans: 1
# nodes: 339.35884363636364
# LV_line_unit: 0.308293200898691
# LV_area_limit: 24.859841143621345
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.6105594350922006
# No_of_LV_lines: 24.859841143621345
# HV_cost: 0
# MV_cost: 69576.15000000001
# LV_cost: 23121.990067401824
# Serv_Trans_cost: 3500
# node_Connection_cost: 33935.88436363637
# The total investment cost is estimated at: 130134.02443103821 $
# The lcoe is: 0.177901563161
#
# The peak load in this cluster is: 273.0998444782177
# The max MV load is: 1936.0
# Cluster_distance: 0.96619
# HV_km: 0
# MV_km: 0.96619
# LV_km: 1.0936386226478378
# Serv_Trans: 7
# nodes: 1362.9411545454545
# LV_line_unit: 0.0028042015965329173
# LV_area_limit: 389.95362272832773
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 6.425878693605122
# No_of_LV_lines: 389.95362272832773
# HV_cost: 0
# MV_cost: 14830.95
# LV_cost: 3280.9158679435136
# Serv_Trans_cost: 24500
# node_Connection_cost: 136294.11545454545
# The total investment cost is estimated at: 178905.98132248898 $
# The lcoe is: 0.0893109873282
#
# The peak load in this cluster is: 58.70198295229488
# The max MV load is: 1936.0
# Cluster_distance: 9.256839999999999
# HV_km: 0
# MV_km: 9.256839999999999
# LV_km: 3.852847268066729
# Serv_Trans: 2
# nodes: 789.1719927272727
# LV_line_unit: 0.03440042203631008
# LV_area_limit: 111.02945178894932
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.3812231282892913
# No_of_LV_lines: 111.02945178894932
# HV_cost: 0
# MV_cost: 56284.19999999999
# LV_cost: 11558.541804200187
# Serv_Trans_cost: 7000
# node_Connection_cost: 78917.19927272727
# The total investment cost is estimated at: 153759.94107692747 $
# The lcoe is: 0.129222747996
#
# The peak load in this cluster is: 139.44518203590704
# The max MV load is: 1936.0
# Cluster_distance: 3.29231
# HV_km: 0
# MV_km: 3.29231
# LV_km: 1.898998909192034
# Serv_Trans: 4
# nodes: 839.6939854545454
# LV_line_unit: 0.013006841843781055
# LV_area_limit: 145.8136435253733
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 3.2810631067272245
# No_of_LV_lines: 145.8136435253733
# HV_cost: 0
# MV_cost: 26461.55
# LV_cost: 5696.996727576102
# Serv_Trans_cost: 14000
# node_Connection_cost: 83969.39854545455
# The total investment cost is estimated at: 130127.94527303065 $
# The lcoe is: 0.0949615537328
#
# The peak load in this cluster is: 110.85280236914876
# The max MV load is: 1936.0
# Cluster_distance: 14.593639999999999
# HV_km: 0
# MV_km: 14.593639999999999
# LV_km: 1.8450098515347
# Serv_Trans: 3
# nodes: 702.5824527272727
# LV_line_unit: 0.02222903435583976
# LV_area_limit: 82.68015472823127
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 2.6083012322152648
# No_of_LV_lines: 82.68015472823127
# HV_cost: 0
# MV_cost: 82968.2
# LV_cost: 5535.0295546041
# Serv_Trans_cost: 10500
# node_Connection_cost: 70258.24527272726
# The total investment cost is estimated at: 169261.47482733137 $
# The lcoe is: 0.107025465511
#
# The peak load in this cluster is: 12.549864175866075
# The max MV load is: 1936.0
# Cluster_distance: 11.06219
# HV_km: 0
# MV_km: 11.06219
# LV_km: 6.112524964206136
# Serv_Trans: 1
# nodes: 186.16601272727272
# LV_line_unit: 1.528131241051534
# LV_area_limit: 3.6072163515267768
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.2952909217850841
# No_of_LV_lines: 3.6072163515267768
# HV_cost: 0
# MV_cost: 65310.95
# LV_cost: 18337.574892618406
# Serv_Trans_cost: 3500
# node_Connection_cost: 18616.601272727272
# The total investment cost is estimated at: 105765.12616534567 $
# The lcoe is: 0.24724201462
#
# The peak load in this cluster is: 11.298665113003786
# The max MV load is: 1936.0
# Cluster_distance: 11.794039999999999
# HV_km: 0
# MV_km: 11.794039999999999
# LV_km: 5.510775235927366
# Serv_Trans: 1
# nodes: 285.61627454545453
# LV_line_unit: 0.9184625393212277
# LV_area_limit: 5.98561156785215
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.2658509438353832
# No_of_LV_lines: 5.98561156785215
# HV_cost: 0
# MV_cost: 68970.2
# LV_cost: 16532.3257077821
# Serv_Trans_cost: 3500
# node_Connection_cost: 28561.627454545454
# The total investment cost is estimated at: 117564.15316232755 $
# The lcoe is: 0.287424175526
#
# The peak load in this cluster is: 78.43744677315193
# The max MV load is: 1936.0
# Cluster_distance: 10.12327
# HV_km: 0
# MV_km: 10.12327
# LV_km: 2.7327861685852697
# Serv_Trans: 2
# nodes: 465.4622545454545
# LV_line_unit: 0.06210877655875613
# LV_area_limit: 43.938073670125654
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.8455869828976925
# No_of_LV_lines: 43.938073670125654
# HV_cost: 0
# MV_cost: 60616.35
# LV_cost: 8198.358505755808
# Serv_Trans_cost: 7000
# node_Connection_cost: 46546.225454545456
# The total investment cost is estimated at: 122360.93396030128 $
# The lcoe is: 0.107697586605
#
# The peak load in this cluster is: 78.5935367219102
# The max MV load is: 1936.0
# Cluster_distance: 6.94107
# HV_km: 0
# MV_km: 6.94107
# LV_km: 2.749552351678133
# Serv_Trans: 2
# nodes: 322.5522363636364
# LV_line_unit: 0.10998209406712531
# LV_area_limit: 24.79203567751517
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.8492596875743577
# No_of_LV_lines: 24.79203567751517
# HV_cost: 0
# MV_cost: 44705.35
# LV_cost: 8248.657055034399
# Serv_Trans_cost: 7000
# node_Connection_cost: 32255.223636363637
# The total investment cost is estimated at: 92209.23069139803 $
# The lcoe is: 0.0998393510248
#
# The peak load in this cluster is: 104.7478636980923
# The max MV load is: 1936.0
# Cluster_distance: 9.30607
# HV_km: 0
# MV_km: 9.30607
# LV_km: 1.8214329153570015
# Serv_Trans: 3
# nodes: 609.90324
# LV_line_unit: 0.029859555989459042
# LV_area_limit: 60.87654710298987
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 2.464655616425701
# No_of_LV_lines: 60.87654710298987
# HV_cost: 0
# MV_cost: 56530.35
# LV_cost: 5464.298746071005
# Serv_Trans_cost: 10500
# node_Connection_cost: 60990.324
# The total investment cost is estimated at: 133484.972746071 $
# The lcoe is: 0.1018936972
#
# The peak load in this cluster is: 55.1407011412646
# The max MV load is: 1936.0
# Cluster_distance: 2.70447
# HV_km: 0
# MV_km: 2.70447
# LV_km: 2.803381268370207
# Serv_Trans: 2
# nodes: 430.4344381818182
# LV_line_unit: 0.10012075958465025
# LV_area_limit: 27.20644560928413
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.2974282621474023
# No_of_LV_lines: 27.20644560928413
# HV_cost: 0
# MV_cost: 23522.35
# LV_cost: 8410.14380511062
# Serv_Trans_cost: 7000
# node_Connection_cost: 43043.443818181826
# The total investment cost is estimated at: 81975.93762329244 $
# The lcoe is: 0.106207930331
#
# The peak load in this cluster is: 8.72285110251494
# The max MV load is: 1936.0
# Cluster_distance: 7.04582
# HV_km: 0
# MV_km: 7.04582
# LV_km: 6.643264071109853
# Serv_Trans: 1
# nodes: 185.2012890909091
# LV_line_unit: 2.214421357036618
# LV_area_limit: 2.4509246999238785
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.2052435553532927
# No_of_LV_lines: 2.4509246999238785
# HV_cost: 0
# MV_cost: 45229.1
# LV_cost: 19929.79221332956
# Serv_Trans_cost: 3500
# node_Connection_cost: 18520.128909090912
# The total investment cost is estimated at: 87179.02112242047 $
# The lcoe is: 0.279076837441
#
# The peak load in this cluster is: 1323.4206970390933
# The max MV load is: 1936.0
# Cluster_distance: 10.423
# HV_km: 0
# MV_km: 41.692
# LV_km: 0.1807238097236035
# Serv_Trans: 30
# nodes: 3538.9090345454547
# LV_line_unit: 9.654049664722409e-05
# LV_area_limit: 1871.1387753344522
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 31.1393105185669
# No_of_LV_lines: 1871.1387753344522
# HV_cost: 0
# MV_cost: 218460.0
# LV_cost: 542.1714291708105
# Serv_Trans_cost: 105000
# node_Connection_cost: 353890.9034545455
# The total investment cost is estimated at: 677893.0748837163 $
# The lcoe is: 0.0864080683926
#
# The peak load in this cluster is: 151.6735416965354
# The max MV load is: 1936.0
# Cluster_distance: 1.19229
# HV_km: 0
# MV_km: 1.19229
# LV_km: 1.3625878785886933
# Serv_Trans: 4
# nodes: 809.7693927272728
# LV_line_unit: 0.012734466155034518
# LV_area_limit: 106.34642893644953
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 3.5687892163890687
# No_of_LV_lines: 106.34642893644953
# HV_cost: 0
# MV_cost: 15961.45
# LV_cost: 4087.76363576608
# Serv_Trans_cost: 14000
# node_Connection_cost: 80976.93927272728
# The total investment cost is estimated at: 115026.15290849336 $
# The lcoe is: 0.0914096803214
#
# The peak load in this cluster is: 11.687025046837231
# The max MV load is: 1936.0
# Cluster_distance: 36.42331
# HV_km: 0
# MV_km: 36.42331
# LV_km: 5.620089622919198
# Serv_Trans: 1
# nodes: 409.63383818181825
# LV_line_unit: 0.5109172384471998
# LV_area_limit: 10.601599618095028
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.2749888246314643
# No_of_LV_lines: 10.601599618095028
# HV_cost: 0
# MV_cost: 192116.55000000002
# LV_cost: 16860.268868757594
# Serv_Trans_cost: 3500
# node_Connection_cost: 40963.38381818183
# The total investment cost is estimated at: 253440.20268693945 $
# The lcoe is: 0.516634395534
#
# The peak load in this cluster is: 17.66384085394361
# The max MV load is: 1936.0
# Cluster_distance: 12.13061
# HV_km: 0
# MV_km: 12.13061
# LV_km: 5.929789522772227
# Serv_Trans: 1
# nodes: 283.83683636363634
# LV_line_unit: 0.5929789522772226
# LV_area_limit: 9.11846867285123
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.41561978479867323
# No_of_LV_lines: 9.11846867285123
# HV_cost: 0
# MV_cost: 70653.05
# LV_cost: 17789.36856831668
# Serv_Trans_cost: 3500
# node_Connection_cost: 28383.683636363632
# The total investment cost is estimated at: 120326.10220468033 $
# The lcoe is: 0.214414493456
#
# The peak load in this cluster is: 91.76121647484148
# The max MV load is: 1936.0
# Cluster_distance: 9.14628
# HV_km: 0
# MV_km: 9.14628
# LV_km: 1.8199599950775107
# Serv_Trans: 3
# nodes: 660.2507
# LV_line_unit: 0.029835409755369028
# LV_area_limit: 60.306417153961824
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 2.159087446466858
# No_of_LV_lines: 60.306417153961824
# HV_cost: 0
# MV_cost: 55731.4
# LV_cost: 5459.879985232532
# Serv_Trans_cost: 10500
# node_Connection_cost: 66025.07
# The total investment cost is estimated at: 137716.34998523255 $
# The lcoe is: 0.106495320614
#
# The peak load in this cluster is: 150.21422142111084
# The max MV load is: 1936.0
# Cluster_distance: 9.79143
# HV_km: 0
# MV_km: 9.79143
# LV_km: 1.341007792444168
# Serv_Trans: 4
# nodes: 767.1090654545455
# LV_line_unit: 0.014115871499412295
# LV_area_limit: 94.86768139365354
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 3.5344522687320197
# No_of_LV_lines: 94.86768139365354
# HV_cost: 0
# MV_cost: 58957.15
# LV_cost: 4023.0233773325035
# Serv_Trans_cost: 14000
# node_Connection_cost: 76710.90654545455
# The total investment cost is estimated at: 153691.07992278706 $
# The lcoe is: 0.0967895205368
#
# The peak load in this cluster is: 159.87136880841436
# The max MV load is: 1936.0
# Cluster_distance: 2.8726700000000003
# HV_km: 0
# MV_km: 2.8726700000000003
# LV_km: 1.3446702557790755
# Serv_Trans: 4
# nodes: 611.3265418181818
# LV_line_unit: 0.019487974721435878
# LV_area_limit: 68.45477886076134
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 3.7616792660803378
# No_of_LV_lines: 68.45477886076134
# HV_cost: 0
# MV_cost: 24363.350000000002
# LV_cost: 4034.0107673372263
# Serv_Trans_cost: 14000
# node_Connection_cost: 61132.65418181818
# The total investment cost is estimated at: 103530.01494915542 $
# The lcoe is: 0.0891583806508
#
# The peak load in this cluster is: 43.00353118571287
# The max MV load is: 1936.0
# Cluster_distance: 7.788589999999999
# HV_km: 0
# MV_km: 7.788589999999999
# LV_km: 5.298771895602739
# Serv_Trans: 1
# nodes: 813.8296581818183
# LV_line_unit: 0.04452749492103142
# LV_area_limit: 118.615251304096
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.0118477926050087
# No_of_LV_lines: 118.615251304096
# HV_cost: 0
# MV_cost: 48942.95
# LV_cost: 15896.315686808217
# Serv_Trans_cost: 3500
# node_Connection_cost: 81382.96581818184
# The total investment cost is estimated at: 149722.23150499005 $
# The lcoe is: 0.146743906017
#
# The peak load in this cluster is: 51.69549208762664
# The max MV load is: 1936.0
# Cluster_distance: 32.84207
# HV_km: 0
# MV_km: 32.84207
# LV_km: 2.7535869572400316
# Serv_Trans: 2
# nodes: 354.1617509090909
# LV_line_unit: 0.1449256293284227
# LV_area_limit: 18.18719030039134
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.2163645197088622
# No_of_LV_lines: 18.18719030039134
# HV_cost: 0
# MV_cost: 174210.35
# LV_cost: 8260.760871720095
# Serv_Trans_cost: 7000
# node_Connection_cost: 35416.17509090909
# The total investment cost is estimated at: 224887.2859626292 $
# The lcoe is: 0.16439324791
#
# The peak load in this cluster is: 59.968395228222185
# The max MV load is: 1936.0
# Cluster_distance: 3.94288
# HV_km: 0
# MV_km: 3.94288
# LV_km: 2.6306879545933137
# Serv_Trans: 2
# nodes: 530.1481836363637
# LV_line_unit: 0.06576719886483284
# LV_area_limit: 39.81042290368884
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.4110210641934633
# No_of_LV_lines: 39.81042290368884
# HV_cost: 0
# MV_cost: 29714.4
# LV_cost: 7892.063863779941
# Serv_Trans_cost: 7000
# node_Connection_cost: 53014.81836363637
# The total investment cost is estimated at: 97621.28222741632 $
# The lcoe is: 0.109077215513
#
# The peak load in this cluster is: 34.236214407706484
# The max MV load is: 1936.0
# Cluster_distance: 4.03466
# HV_km: 0
# MV_km: 4.03466
# LV_km: 5.29443776300062
# Serv_Trans: 1
# nodes: 628.8640490909091
# LV_line_unit: 0.08679406168853476
# LV_area_limit: 60.313342850407324
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.805557986063682
# No_of_LV_lines: 60.313342850407324
# HV_cost: 0
# MV_cost: 30173.3
# LV_cost: 15883.31328900186
# Serv_Trans_cost: 3500
# node_Connection_cost: 62886.40490909091
# The total investment cost is estimated at: 112443.01819809277 $
# ...
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.4655684805681148
# No_of_LV_lines: 7.711577791221318
# HV_cost: 0
# MV_cost: 51500.35
# LV_cost: 3303.9775633210324
# Serv_Trans_cost: 7000
# node_Connection_cost: 32426.24036363636
# The total investment cost is estimated at: 94230.56792695739 $
# The lcoe is: 0.106739983121
#
# The peak load in this cluster is: 266.9031927148266
# The max MV load is: 1936.0
# Cluster_distance: 0.35388000000000003
# HV_km: 0
# MV_km: 0.35388000000000003
# LV_km: 0.312188911379688
# Serv_Trans: 6
# nodes: 1049.5910963636363
# LV_line_unit: 0.004591013402642471
# LV_area_limit: 67.57985063198076
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 6.280075122701803
# No_of_LV_lines: 67.57985063198076
# HV_cost: 0
# MV_cost: 11769.4
# LV_cost: 936.566734139064
# Serv_Trans_cost: 21000
# node_Connection_cost: 104959.10963636363
# The total investment cost is estimated at: 138665.0763705027 $
# The lcoe is: 0.0865565057512
#
# The peak load in this cluster is: 17.162488189315813
# The max MV load is: 1936.0
# Cluster_distance: 4.45352
# HV_km: 0
# MV_km: 4.45352
# LV_km: 2.2447881761627064
# Serv_Trans: 1
# nodes: 185.56982545454545
# LV_line_unit: 1.1223940880813532
# LV_area_limit: 1.6585618364955879
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.4038232515133132
# No_of_LV_lines: 1.6585618364955879
# HV_cost: 0
# MV_cost: 32267.600000000002
# LV_cost: 6734.3645284881195
# Serv_Trans_cost: 3500
# node_Connection_cost: 18556.982545454546
# The total investment cost is estimated at: 61058.94707394266 $
# The lcoe is: 0.148289616673
#
# The peak load in this cluster is: 8.04659850034753
# The max MV load is: 1936.0
# Cluster_distance: 8.24427
# HV_km: 0
# MV_km: 8.24427
# LV_km: 2.2237258294334317
# Serv_Trans: 1
# nodes: 195.69397636363635
# LV_line_unit: 2.2237258294334317
# LV_area_limit: 0.8371355746109647
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.1893317294199419
# No_of_LV_lines: 0.8371355746109647
# HV_cost: 0
# MV_cost: 51221.35
# LV_cost: 6671.177488300295
# Serv_Trans_cost: 3500
# node_Connection_cost: 19569.397636363636
# The total investment cost is estimated at: 80961.92512466393 $
# The lcoe is: 0.280444464759
#
# The peak load in this cluster is: 15.763010661496548
# The max MV load is: 1936.0
# Cluster_distance: 0.55518
# HV_km: 0
# MV_km: 0.55518
# LV_km: 3.192262942733028
# Serv_Trans: 1
# nodes: 152.47069636363636
# LV_line_unit: 1.596131471366514
# LV_area_limit: 1.1662823729716068
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.3708943685058011
# No_of_LV_lines: 1.1662823729716068
# HV_cost: 0
# MV_cost: 12775.9
# LV_cost: 9576.788828199084
# Serv_Trans_cost: 3500
# node_Connection_cost: 15247.069636363636
# The total investment cost is estimated at: 41099.75846456272 $
# The lcoe is: 0.12897939111
#
# The peak load in this cluster is: 17.702891347713052
# The max MV load is: 1936.0
# Cluster_distance: 26.595090000000003
# HV_km: 0
# MV_km: 26.595090000000003
# LV_km: 1.980731501900246
# Serv_Trans: 1
# nodes: 198.57166000000004
# LV_line_unit: 0.990365750950123
# LV_area_limit: 1.8796288120970677
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.41653861994618946
# No_of_LV_lines: 1.8796288120970677
# HV_cost: 0
# MV_cost: 142975.45
# LV_cost: 5942.194505700738
# Serv_Trans_cost: 3500
# node_Connection_cost: 19857.166000000005
# The total investment cost is estimated at: 172274.81050570073 $
# The lcoe is: 0.273735405734
#
# The peak load in this cluster is: 13.77821165761311
# The max MV load is: 1936.0
# Cluster_distance: 14.75622
# HV_km: 0
# MV_km: 14.75622
# LV_km: 3.0329998595430436
# Serv_Trans: 1
# nodes: 103.05236363636364
# LV_line_unit: 3.0329998595430436
# LV_area_limit: 0.6137026331021443
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.32419321547324964
# No_of_LV_lines: 0.6137026331021443
# HV_cost: 0
# MV_cost: 83781.1
# LV_cost: 9098.999578629131
# Serv_Trans_cost: 3500
# node_Connection_cost: 10305.236363636364
# The total investment cost is estimated at: 106685.33594226549 $
# The lcoe is: 0.233332607172
#
# The peak load in this cluster is: 19.128614237309165
# The max MV load is: 1936.0
# Cluster_distance: 13.63248
# HV_km: 0
# MV_km: 13.63248
# LV_km: 1.8738047939155371
# Serv_Trans: 1
# nodes: 259.60640181818184
# LV_line_unit: 0.6246015979718457
# LV_area_limit: 2.980043608668291
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.4500850408778627
# No_of_LV_lines: 2.980043608668291
# HV_cost: 0
# MV_cost: 78162.4
# LV_cost: 5621.414381746611
# Serv_Trans_cost: 3500
# node_Connection_cost: 25960.640181818184
# The total investment cost is estimated at: 113244.4545635648 $
# The lcoe is: 0.196292983891
#
# The peak load in this cluster is: 40.42189235011307
# The max MV load is: 1936.0
# Cluster_distance: 2.05408
# HV_km: 0
# MV_km: 2.05408
# LV_km: 1.8771990586571452
# Serv_Trans: 1
# nodes: 303.31949818181823
# LV_line_unit: 0.23464988233214315
# LV_area_limit: 7.9320730166206355
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.9511033494144252
# No_of_LV_lines: 7.9320730166206355
# HV_cost: 0
# MV_cost: 20270.4
# LV_cost: 5631.597175971436
# Serv_Trans_cost: 3500
# node_Connection_cost: 30331.949818181824
# The total investment cost is estimated at: 59733.94699415326 $
# The lcoe is: 0.106026964702
#
# The peak load in this cluster is: 66.64785684218742
# The max MV load is: 1936.0
# Cluster_distance: 2.20447
# HV_km: 0
# MV_km: 2.20447
# LV_km: 0.9419366422655415
# Serv_Trans: 2
# nodes: 421.5217872727273
# LV_line_unit: 0.08563060384232196
# LV_area_limit: 10.81272300385653
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.5681848668749983
# No_of_LV_lines: 10.81272300385653
# HV_cost: 0
# MV_cost: 21022.35
# LV_cost: 2825.8099267966245
# Serv_Trans_cost: 7000
# node_Connection_cost: 42152.17872727273
# The total investment cost is estimated at: 73000.33865406935 $
# The lcoe is: 0.0982559198475
#
# The peak load in this cluster is: 24.279538944367324
# The max MV load is: 1936.0
# Cluster_distance: 6.49996
# HV_km: 0
# MV_km: 6.49996
# LV_km: 2.0506460495288965
# Serv_Trans: 1
# nodes: 331.32379272727275
# LV_line_unit: 0.3417743415881494
# LV_area_limit: 5.4179608433900235
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.5712832692792311
# No_of_LV_lines: 5.4179608433900235
# HV_cost: 0
# MV_cost: 42499.8
# LV_cost: 6151.93814858669
# Serv_Trans_cost: 3500
# node_Connection_cost: 33132.379272727274
# The total investment cost is estimated at: 85284.11742131397 $
# The lcoe is: 0.147373104294
#
# The peak load in this cluster is: 53.68760518523457
# The max MV load is: 1936.0
# Cluster_distance: 5.63384
# HV_km: 0
# MV_km: 5.63384
# LV_km: 0.8805499193464348
# Serv_Trans: 2
# nodes: 303.9609545454545
# LV_line_unit: 0.17610998386928695
# LV_area_limit: 4.570893610424015
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 1.2632377690643428
# No_of_LV_lines: 4.570893610424015
# HV_cost: 0
# MV_cost: 38169.2
# LV_cost: 2641.6497580393043
# Serv_Trans_cost: 7000
# node_Connection_cost: 30396.09545454545
# The total investment cost is estimated at: 78206.94521258475 $
# The lcoe is: 0.105599075933
#
# The peak load in this cluster is: 1.0335999794097244
# The max MV load is: 1936.0
# Cluster_distance: 53.742630000000005
# HV_km: 0
# MV_km: 53.742630000000005
# LV_km: 149.0082415038402
# Serv_Trans: 1
# nodes: 33.766012727272724
# LV_line_unit: 149.0082415038402
# LV_area_limit: 0.009759191742173018
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.024319999515522925
# No_of_LV_lines: 0.024319999515522925
# HV_cost: 0
# MV_cost: 278713.15
# LV_cost: 447024.7245115206
# Serv_Trans_cost: 3500
# node_Connection_cost: 3376.6012727272723
# The total investment cost is estimated at: 732614.4757842479 $
# The lcoe is: 14.4782341055
#
# The peak load in this cluster is: 99.95103287939293
# The max MV load is: 1936.0
# Cluster_distance: 3.54731
# HV_km: 0
# MV_km: 3.54731
# LV_km: 0.48230381137646894
# Serv_Trans: 3
# nodes: 338.40239818181817
# LV_line_unit: 0.08038396856274482
# LV_area_limit: 5.676007394980255
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 2.3517890089268922
# No_of_LV_lines: 5.676007394980255
# HV_cost: 0
# MV_cost: 27736.55
# LV_cost: 1446.9114341294069
# Serv_Trans_cost: 10500
# node_Connection_cost: 33840.23981818181
# The total investment cost is estimated at: 73523.70125231122 $
# The lcoe is: 0.0909467557509
#
# The peak load in this cluster is: 4.074453075730597
# The max MV load is: 1936.0
# Cluster_distance: 1.57285
# HV_km: 0
# MV_km: 1.57285
# LV_km: 18.425342679746954
# Serv_Trans: 1
# nodes: 63.58987818181818
# LV_line_unit: 18.425342679746954
# LV_area_limit: 0.0742846428307947
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.09586948413483758
# No_of_LV_lines: 0.09586948413483758
# HV_cost: 0
# MV_cost: 17864.25
# LV_cost: 55276.02803924086
# Serv_Trans_cost: 3500
# node_Connection_cost: 6358.987818181818
# The total investment cost is estimated at: 82999.26585742268 $
# The lcoe is: 0.489915598126
#
# The peak load in this cluster is: 1.0872549136744636
# The max MV load is: 1936.0
# Cluster_distance: 20.00459
# HV_km: 0
# MV_km: 20.00459
# LV_km: 140.9759266829923
# Serv_Trans: 1
# nodes: 33.91362363636364
# LV_line_unit: 140.9759266829923
# LV_area_limit: 0.009708891668276057
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.0255824685570462
# No_of_LV_lines: 0.0255824685570462
# HV_cost: 0
# MV_cost: 110022.95
# LV_cost: 422927.78004897694
# Serv_Trans_cost: 3500
# node_Connection_cost: 3391.3623636363636
# The total investment cost is estimated at: 539842.0924126133 $
# The lcoe is: 10.1648630663
#
# The peak load in this cluster is: 23.356326109769125
# The max MV load is: 1936.0
# Cluster_distance: 11.50942
# HV_km: 0
# MV_km: 11.50942
# LV_km: 1.9438968654756936
# Serv_Trans: 1
# nodes: 220.39262
# LV_line_unit: 0.6479656218252312
# LV_area_limit: 2.112334287341513
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.5495606143475088
# No_of_LV_lines: 2.112334287341513
# HV_cost: 0
# MV_cost: 67547.1
# LV_cost: 5831.690596427081
# Serv_Trans_cost: 3500
# node_Connection_cost: 22039.262
# The total investment cost is estimated at: 98918.0525964271 $
# The lcoe is: 0.162055352865
#
# The peak load in this cluster is: 3.8201465834167436
# The max MV load is: 1936.0
# Cluster_distance: 0.45542
# HV_km: 0
# MV_km: 0.45542
# LV_km: 55.22747933470667
# Serv_Trans: 1
# nodes: 25.291614545454546
# LV_line_unit: 55.22747933470667
# LV_area_limit: 0.024782590414911054
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.08988580196274691
# No_of_LV_lines: 0.08988580196274691
# HV_cost: 0
# MV_cost: 12277.1
# LV_cost: 165682.43800412002
# Serv_Trans_cost: 3500
# node_Connection_cost: 2529.1614545454545
# The total investment cost is estimated at: 183988.69945866548 $
# The lcoe is: 1.05462878167
#
# The peak load in this cluster is: 24.313212143713756
# The max MV load is: 1936.0
# Cluster_distance: 13.44103
# HV_km: 0
# MV_km: 13.44103
# LV_km: 1.493575346893492
# Serv_Trans: 1
# nodes: 312.2709254545454
# LV_line_unit: 0.373393836723373
# LV_area_limit: 3.665352411839448
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.5720755798520883
# No_of_LV_lines: 3.665352411839448
# HV_cost: 0
# MV_cost: 77205.15
# LV_cost: 4480.726040680476
# Serv_Trans_cost: 3500
# node_Connection_cost: 31227.092545454543
# The total investment cost is estimated at: 116412.96858613502 $
# The lcoe is: 0.173289481068
#
# The peak load in this cluster is: 9.611733991553823
# The max MV load is: 1936.0
# Cluster_distance: 16.267229999999998
# HV_km: 0
# MV_km: 16.267229999999998
# LV_km: 3.0315813162222924
# Serv_Trans: 1
# nodes: 136.47529454545455
# LV_line_unit: 3.0315813162222924
# LV_area_limit: 0.45138818895519933
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.22615844686008996
# No_of_LV_lines: 0.45138818895519933
# HV_cost: 0
# MV_cost: 91336.15
# LV_cost: 9094.743948666877
# Serv_Trans_cost: 3500
# node_Connection_cost: 13647.529454545454
# The total investment cost is estimated at: 117578.42340321232 $
# The lcoe is: 0.324560865106
#
# The peak load in this cluster is: 35.76451967555863
# The max MV load is: 1936.0
# Cluster_distance: 2.5626900000000004
# HV_km: 0
# MV_km: 2.5626900000000004
# LV_km: 1.3785783331659969
# Serv_Trans: 1
# nodes: 333.4545345454545
# LV_line_unit: 0.22976305552766615
# LV_area_limit: 5.912090596464213
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.8415181100131442
# No_of_LV_lines: 5.912090596464213
# HV_cost: 0
# MV_cost: 22813.450000000004
# LV_cost: 4135.73499949799
# Serv_Trans_cost: 3500
# node_Connection_cost: 33345.45345454545
# The total investment cost is estimated at: 63794.638454043445 $
# The lcoe is: 0.112244210668
#
# The peak load in this cluster is: 6.860889964374041
# The max MV load is: 1936.0
# Cluster_distance: 11.149989999999999
# HV_km: 0
# MV_km: 11.149989999999999
# LV_km: 11.896380504702853
# Serv_Trans: 1
# nodes: 59.20366727272728
# LV_line_unit: 11.896380504702853
# LV_area_limit: 0.11418262886455388
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.1614327050440951
# No_of_LV_lines: 0.1614327050440951
# HV_cost: 0
# MV_cost: 65749.95
# LV_cost: 35689.14151410856
# Serv_Trans_cost: 3500
# node_Connection_cost: 5920.366727272728
# The total investment cost is estimated at: 110859.45824138129 $
# The lcoe is: 0.404321376675
#
# The peak load in this cluster is: 10.973361705326676
# The max MV load is: 1936.0
# Cluster_distance: 10.22515
# HV_km: 0
# MV_km: 10.22515
# LV_km: 4.610755676018871
# Serv_Trans: 1
# nodes: 88.34055454545454
# LV_line_unit: 4.610755676018871
# LV_area_limit: 0.29460680535839356
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.2581967460076865
# No_of_LV_lines: 0.29460680535839356
# HV_cost: 0
# MV_cost: 61125.75
# LV_cost: 13832.267028056614
# Serv_Trans_cost: 3500
# node_Connection_cost: 8834.055454545454
# The total investment cost is estimated at: 87292.07248260206 $
# The lcoe is: 0.237637443252
#
# The peak load in this cluster is: 5.783340369433544
# The max MV load is: 1936.0
# Cluster_distance: 3.38875
# HV_km: 0
# MV_km: 3.38875
# LV_km: 17.397052857780622
# Serv_Trans: 1
# nodes: 49.37811818181819
# LV_line_unit: 17.397052857780622
# LV_area_limit: 0.07807759228555242
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.1360785969278481
# No_of_LV_lines: 0.1360785969278481
# HV_cost: 0
# MV_cost: 26943.75
# LV_cost: 52191.15857334187
# Serv_Trans_cost: 3500
# node_Connection_cost: 4937.811818181819
# The total investment cost is estimated at: 87572.72039152369 $
# The lcoe is: 0.383678358981
#
# The peak load in this cluster is: 15.625644022951022
# The max MV load is: 1936.0
# Cluster_distance: 8.96623
# HV_km: 0
# MV_km: 8.96623
# LV_km: 2.140088603127883
# Serv_Trans: 1
# nodes: 205.40313090909092
# LV_line_unit: 1.0700443015639416
# LV_area_limit: 1.269405386314122
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.36766221230472995
# No_of_LV_lines: 1.269405386314122
# HV_cost: 0
# MV_cost: 54831.149999999994
# LV_cost: 6420.26580938365
# Serv_Trans_cost: 3500
# node_Connection_cost: 20540.31309090909
# The total investment cost is estimated at: 85291.72890029274 $
# The lcoe is: 0.186911314886
#
# The peak load in this cluster is: 8.904639575669885
# The max MV load is: 1936.0
# Cluster_distance: 45.29544
# HV_km: 0
# MV_km: 45.29544
# LV_km: 2.695302535401368
# Serv_Trans: 1
# nodes: 157.9292090909091
# LV_line_unit: 2.695302535401368
# LV_area_limit: 0.5039508486188288
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.20952093119223258
# No_of_LV_lines: 0.5039508486188288
# HV_cost: 0
# MV_cost: 236477.19999999998
# LV_cost: 8085.907606204104
# Serv_Trans_cost: 3500
# node_Connection_cost: 15792.92090909091
# The total investment cost is estimated at: 263856.028515295 $
# The lcoe is: 0.678084626233
#
# The peak load in this cluster is: 2.3329555805556232
# The max MV load is: 1936.0
# Cluster_distance: 8.11974
# HV_km: 0
# MV_km: 8.11974
# LV_km: 4.541008221681746
# Serv_Trans: 1
# nodes: 281.6737818181818
# LV_line_unit: 4.541008221681746
# LV_area_limit: 0.29910097795352336
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.05489307248366172
# No_of_LV_lines: 0.29910097795352336
# HV_cost: 0
# MV_cost: 50598.700000000004
# LV_cost: 13623.024665045237
# Serv_Trans_cost: 3500
# node_Connection_cost: 28167.378181818178
# The total investment cost is estimated at: 95889.10284686342 $
# The lcoe is: 0.911159927187

# %% [markdown]
# ## Testing of results

# %% [markdown]
# #### First we take a look on general statistics of the results

# %%
# This command shows some general statistics on the results
df["lcoe"].describe().transpose()
# Out:
# count    300.000000
# mean       1.453411
# std       19.859530
# min        0.082842
# 25%        0.103233
# 50%        0.130240
# 75%        0.198621
# max      343.790166
# Name: lcoe, dtype: float64

# %% [markdown]
# #### Then we check for extreme values for troubleshooting

# %%
x=df["lcoe"].argmax()
print("maximum lcoe achieved achieved in index {x} with the following inputs:\n".format(x=x))
print (df.iloc[x])

people = df.iloc[x]["Pop"]
access_target = df.iloc[x]["ResidentialDemandTierCustom"]
ppl_per_hh = df.iloc[x]["NumPeoplePerHH"]
productive_demand = df.iloc[x]["Productive_demand"]
productive_nodes = df.iloc[x]["Productive_nodes"]
cluster_area = df.iloc[x]["GridCellArea"]
elec_dist = df.iloc[x]["PlannedHVLineDist"]

print ("\n Using these inputs: \n people:{a} \n target: {b} \n ppl_per_hh: {c} \n product_demand:{d} \n product_nodes:{e} \n area:{f} \n distance_from_grid: {g}".format(a=people,b=access_target,c=ppl_per_hh,d=productive_demand,e=productive_nodes,f=cluster_area,g=elec_dist))
print ("\n The results look like this: \n")
test = calc_lcoe(people, access_target, ppl_per_hh, productive_demand, productive_nodes,cluster_area, elec_dist)
# Out:
# maximum lcoe achieved achieved in index 200 with the following inputs:
#
# X_deg                            35.4202
# Y_deg                           -15.7972
# GridCellArea                     1.99163
# AUTO                               14728
# Pop                              76.8822
# CurrentHVLineDist                21.3657
# PlannedHVLineDist                21.3657
# TransformerDist                  7.70674
# CurrentMVLineDist                7.70674
# PlannedMVLineDist                7.70674
# ResidentialDemandTierCustom           26
# IsUrban                                0
# PerCapitaDemand                     43.8
# Productive_demand                      0
# Productive_nodes                       0
# AgriDemand                             0
# Conflict                               0
# CommercialDemand                       0
# NumPeoplePerHH                       5.5
# TotalEnergyPerCell               5539.19
# MG_Hydro2030                          99
# MG_PV2030                       0.753921
# MG_Wind2030                           99
# MG_Diesel2030                    1.17499
# SA_Diesel2030                   0.724158
# SA_PV2030                       0.391377
# Minimum_Tech_Off_grid2030      SA_PV2030
# Minimum_LCOE_Off_grid2030       0.391377
# lcoe                              343.79
# Name: 200, dtype: object
#
#  Using these inputs:
#  people:76.88221
#  target: 26.0
#  ppl_per_hh: 5.5
#  product_demand:0
#  product_nodes:0
#  area:1.99163
#  distance_from_grid: 21.3657
#
#  The results look like this:
#
# The peak load in this cluster is: 0.268457891485
# The max MV load is: 1936.0
# Cluster_distance: 21.3657
# HV_km: 0
# MV_km: 21.3657
# LV_km: 1473.14434088
# Serv_Trans: 1
# nodes: 13.9785836364
# LV_line_unit: 1473.14434088
# LV_area_limit: 0.00270391698184
# LV_line_amperage 208.33333333333334
# LV_capacity_limit: 0.00631665627024
# No_of_LV_lines: 0.00631665627024
# HV_cost: 0
# MV_cost: 116828.5
# LV_cost: 4419433.02264
# Serv_Trans_cost: 3500
# node_Connection_cost: 1397.85836364
# The total investment cost is estimated at: 4541159.381 $
# The lcoe is: 343.790166293

# %% [markdown]
# ## Mapping of electrification results
#
# The following code generates a map showing the calculated cost of electricity at each point. The map can be accessed using the link below.

# %%
#Define limits for map rendering
x_ave = df["X_deg"].mean()
y_ave = df["Y_deg"].mean()
lcoe_ave = df["lcoe"].median()

# Create the map using folium module
map_lcoe = folium.Map(location=[y_ave,x_ave], zoom_start=6, control_scale=True)

# Definition of a function that returns different color names based on lcoe result categorization
# Colors are in Hexa-code e.g. #RRGGBB
def colorvalue(x):
    if x <= 0.5:
        return "#ADFF2F"
    elif x >= 0.5 and x < 2:
        return "#32CD32"
    elif x >= 2 and x < 10:
        return "#228B22"
    elif x >= 10 and x < 100:
        return "#008000"
    elif x >= 100 and x < 500:
        return "#006400"
    else:
        return "#000000" 

# The we create a marker for each cluster; 
# We pass coordinates, lcoe value and size as attributes to appear on the rendered map
for index, row in df.iterrows():
    lcoe = row["lcoe"]
    area = row["GridCellArea"]
    color_code = colorvalue(lcoe)
    radius_size = radius_sizing(area)
    #print (color_code)
    #print (radius_size)
    folium.CircleMarker([row["Y_deg"], row["X_deg"]],
                        radius=2,
                        color=color_code,
                        popup="lcoe: {:.2} USD/kWh, area: {:.2} sq.km".format(row["lcoe"], row["GridCellArea"]),
                        fill = True,
                        fill_opacity=0,
                       ).add_to(map_lcoe)

# We define the limits of the legend and fix its printout format
# We use branca module to create a colormap legend and then add legend to the map
min_lcoe = df["lcoe"].min()
max_lcoe = df["lcoe"].max()
min_lcoe = float("{0:.2f}".format(min_lcoe))
max_lcoe = float("{0:.2f}".format(max_lcoe))
legend = cm.LinearColormap(['#ADFF2F','#32CD32','#228B22','#008000','#006400','#000000'], 
                           index=None, vmin=min_lcoe, vmax=max_lcoe)
legend.add_to(map_lcoe)    

# Create a new directory where the map(s) can be saved
try:
    os.makedirs('maps')
except FileExistsError:
    pass

map_lcoe_output = 'maps/map_{}{}_lcoe.html'.format("Clusters", "Malawi")
map_lcoe.save(map_lcoe_output)

# Finally add the link that leads to the final map output
display(Markdown('<a href="{}" target="_blank">Click here to render the map of electricity cost</a>'.format(map_lcoe_output)))
# Out:
# <a href="maps/map_ClustersMalawi_lcoe.html" target="_blank">Click here to render the map of electricity cost</a>

# %% [markdown]
# ### The methodology presented below is based on the following sources:
#
# 1. Grid Planning for the Future Grid Optimizing Topology and Technology Considering Spatial and Temporal Effects by Hakan Ergun (ABB)
# * Generation of Realistic Distribution Grid Topologies Based on Spatial Load Maps by Viktor Lenz ([link](file:///C:/Users/alekor/Box%20Sync/KTH-dESA/Projects/OnSSET/LCoE%20Calculation%20OnSSET/ETH_Thesis_Lenz-SA-2015.pdf))
#
# as well as
#
# 3. https://electronics.stackexchange.com/questions/262429/how-many-customers-can-be-connected-to-a-single-wire-earth-return-node-pole-in-a
# * https://ieeexplore.ieee.org/document/7343994
# * https://library.e.abb.com/public/469882604aaf41bdafd1d391132e6bf9/SSVT_SSMV%20Applications_PPHVITSSVTAPP1115FL.pdf
# * https://scholarsmine.mst.edu/cgi/viewcontent.cgi?article=6061&context=masters_theses
# * https://pure.tue.nl/ws/files/46798428/449349-1.pdf
# * http://www.stonepower.se/Images/SWER.pdf
# * https://arxiv.org/pdf/1207.5857.pdf
# * https://www.esmap.org/sites/default/files/esmap-files/Rpt_gridextensionesm227.pdf
# * https://www-emeraldinsight-com.focus.lib.kth.se/doi/full/10.1108/17506221211259673
# * Power Distribution Planning Reference Book Second Edition, Revised and Expanded (Book) by H. Lee Willis
#
# * https://betterexplained.com/articles/techniques-for-adding-the-numbers-1-to-100/
